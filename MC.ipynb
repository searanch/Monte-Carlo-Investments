# %%
using Random, Distributions, DataFrames, CSV, Plots, StatsPlots

# %% [markdown]
# Monte Carlo Model to model potential investment returns.
# Assumptions: Based on 20 years of an all stock portfolio. Using historical return of SP 500. Starting investment of $10,000 with 21k per year in addtional contributions.

# %%
function y1()
    random = rand(Truncated(Normal(.077, .19), -.47, .46), 10000)
    a = reshape(random, length(random),1)
    df = DataFrame(a,["y1return"])
    df2 = DataFrame(invest=repeat(10000:10000, inner=10000))
    df3 = DataFrame(y1addfunds=repeat(21000:21000,inner=10000))
    merged = hcat(df, df2,df3)
    merged[!,:y1total] = merged[!,:y1return] .* merged[!,:invest] + merged[!,:invest] + merged[!, :y1addfunds]
    merged
end

y1()

function y2()
    random = rand(Truncated(Normal(.077, .19), -.47, .46), 10000)
    a = reshape(random, length(random),1)
    df = DataFrame(a,["y2return"])

    merged = y1()
    df2 = DataFrame(y2addfunds=repeat(21000:21000,inner=10000))
    merged2 = hcat(merged,df,df2)
    
    merged2[!,:y2total] = merged2[!,:y2return] .* merged2[!,:y1total] + merged2[!,:y1total] + merged2[!, :y2addfunds]
    # merged
    merged2
end

y2()

function y3()
    random = rand(Truncated(Normal(.077, .19), -.47, .46), 10000)
    a = reshape(random, length(random),1)
    df = DataFrame(a,["y3return"])

    merged = y2()
    df2 = DataFrame(y3addfunds=repeat(21000:21000,inner=10000))
    merged2 = hcat(merged,df,df2)
    
    merged2[!,:y3total] = merged2[!,:y3return] .* merged2[!,:y2total] + merged2[!,:y2total] + merged2[!, :y3addfunds]
    # merged
    merged2
end

y3()

function y4()
    random = rand(Truncated(Normal(.077, .19), -.47, .46), 10000)
    a = reshape(random, length(random),1)
    df = DataFrame(a,["y4return"])

    merged = y3()
    df2 = DataFrame(y4addfunds=repeat(21000:21000,inner=10000))
    merged2 = hcat(merged,df,df2)
    
    merged2[!,:y4total] = merged2[!,:y4return] .* merged2[!,:y3total] + merged2[!,:y3total] + merged2[!, :y4addfunds]
    # merged
    merged2
end
y4()

function y5()
    random = rand(Truncated(Normal(.077, .19), -.47, .46), 10000)
    a = reshape(random, length(random),1)
    df = DataFrame(a,["y5return"])

    merged = y4()
    df2 = DataFrame(y5addfunds=repeat(21000:21000,inner=10000))
    merged2 = hcat(merged,df,df2)
    
    merged2[!,:y5total] = merged2[!,:y5return] .* merged2[!,:y4total] + merged2[!,:y4total] + merged2[!, :y5addfunds]
    # merged
    merged2
end

y5()

# %%
function y6()
    random = rand(Truncated(Normal(.077, .19), -.47, .46), 10000)
    a = reshape(random, length(random),1)
    df = DataFrame(a,["y6return"])

    merged = y5()
    df2 = DataFrame(y6addfunds=repeat(21000:21000,inner=10000))
    merged2 = hcat(merged,df,df2)
    
    merged2[!,:y6total] = merged2[!,:y6return] .* merged2[!,:y5total] + merged2[!,:y5total] + merged2[!, :y6addfunds]
    # merged
    merged2
end

y6()

function y7()
    random = rand(Truncated(Normal(.077, .19), -.47, .46), 10000)
    a = reshape(random, length(random),1)
    df = DataFrame(a,["y7return"])

    merged = y6()
    df2 = DataFrame(y7addfunds=repeat(21000:21000,inner=10000))
    merged2 = hcat(merged,df,df2)
    
    merged2[!,:y7total] = merged2[!,:y7return] .* merged2[!,:y6total] + merged2[!,:y6total] + merged2[!, :y7addfunds]
    # merged
    merged2
end

y7()

function y8()
    random = rand(Truncated(Normal(.077, .19), -.47, .46), 10000)
    a = reshape(random, length(random),1)
    df = DataFrame(a,["y8return"])

    merged = y7()
    df2 = DataFrame(y8addfunds=repeat(21000:21000,inner=10000))
    merged2 = hcat(merged,df,df2)
    
    merged2[!,:y8total] = merged2[!,:y8return] .* merged2[!,:y7total] + merged2[!,:y7total] + merged2[!, :y8addfunds]
    # merged
    merged2
end

y8()

function y9()
    random = rand(Truncated(Normal(.077, .19), -.47, .46), 10000)
    a = reshape(random, length(random),1)
    df = DataFrame(a,["y9return"])

    merged = y8()
    df2 = DataFrame(y9addfunds=repeat(21000:21000,inner=10000))
    merged2 = hcat(merged,df,df2)
    
    merged2[!,:y9total] = merged2[!,:y9return] .* merged2[!,:y8total] + merged2[!,:y8total] + merged2[!, :y9addfunds]
    # merged
    merged2
end

y9()

function y10()
    random = rand(Truncated(Normal(.077, .19), -.47, .46), 10000)
    a = reshape(random, length(random),1)
    df = DataFrame(a,["y10return"])

    merged = y9()
    df2 = DataFrame(y10addfunds=repeat(21000:21000,inner=10000))
    merged2 = hcat(merged,df,df2)
    
    merged2[!,:y10total] = merged2[!,:y10return] .* merged2[!,:y9total] + merged2[!,:y9total] + merged2[!, :y10addfunds]
    # merged
    merged2
end

y10()

# %%
function y11()
    random = rand(Truncated(Normal(.077, .19), -.47, .46), 10000)
    a = reshape(random, length(random),1)
    df = DataFrame(a,["y11return"])

    merged = y10()
    df2 = DataFrame(y11addfunds=repeat(21000:21000,inner=10000))
    merged2 = hcat(merged,df,df2)
    
    merged2[!,:y11total] = merged2[!,:y11return] .* merged2[!,:y10total] + merged2[!,:y10total] + merged2[!, :y11addfunds]
    # merged
    merged2
end

y11()

function y12()
    random = rand(Truncated(Normal(.077, .19), -.47, .46), 10000)
    a = reshape(random, length(random),1)
    df = DataFrame(a,["y12return"])

    merged = y11()
    df2 = DataFrame(y12addfunds=repeat(21000:21000,inner=10000))
    merged2 = hcat(merged,df,df2)
    
    merged2[!,:y12total] = merged2[!,:y12return] .* merged2[!,:y11total] + merged2[!,:y11total] + merged2[!, :y12addfunds]
    # merged
    merged2
end

y12()


function y13()
    random = rand(Truncated(Normal(.077, .19), -.47, .46), 10000)
    a = reshape(random, length(random),1)
    df = DataFrame(a,["y13return"])

    merged = y12()
    df2 = DataFrame(y13addfunds=repeat(21000:21000,inner=10000))
    merged2 = hcat(merged,df,df2)
    
    merged2[!,:y13total] = merged2[!,:y13return] .* merged2[!,:y12total] + merged2[!,:y12total] + merged2[!, :y13addfunds]
    # merged
    merged2
end

y13()


function y14()
    random = rand(Truncated(Normal(.077, .19), -.47, .46), 10000)
    a = reshape(random, length(random),1)
    df = DataFrame(a,["y14return"])

    merged = y13()
    df2 = DataFrame(y14addfunds=repeat(21000:21000,inner=10000))
    merged2 = hcat(merged,df,df2)
    
    merged2[!,:y14total] = merged2[!,:y13return] .* merged2[!,:y13total] + merged2[!,:y13total] + merged2[!, :y14addfunds]
    # merged
    merged2
end

y14()

function y15()
    random = rand(Truncated(Normal(.077, .19), -.47, .46), 10000)
    a = reshape(random, length(random),1)
    df = DataFrame(a,["y15return"])

    merged = y14()
    df2 = DataFrame(y15addfunds=repeat(21000:21000,inner=10000))
    merged2 = hcat(merged,df,df2)
    
    merged2[!,:y15total] = merged2[!,:y14return] .* merged2[!,:y14total] + merged2[!,:y14total] + merged2[!, :y15addfunds]
    # merged
    merged2
end

y15()


function y16()
    random = rand(Truncated(Normal(.077, .19), -.47, .46), 10000)
    a = reshape(random, length(random),1)
    df = DataFrame(a,["y16return"])

    merged = y15()
    df2 = DataFrame(y16addfunds=repeat(21000:21000,inner=10000))
    merged2 = hcat(merged,df,df2)
    
    merged2[!,:y16total] = merged2[!,:y15return] .* merged2[!,:y15total] + merged2[!,:y15total] + merged2[!, :y16addfunds]
    # merged
    merged2
end

y16()

function y17()
    random = rand(Truncated(Normal(.077, .19), -.47, .46), 10000)
    a = reshape(random, length(random),1)
    df = DataFrame(a,["y17return"])

    merged = y16()
    df2 = DataFrame(y17addfunds=repeat(21000:21000,inner=10000))
    merged2 = hcat(merged,df,df2)
    
    merged2[!,:y17total] = merged2[!,:y16return] .* merged2[!,:y16total] + merged2[!,:y16total] + merged2[!, :y17addfunds]
    # merged
    merged2
end

y17()

function y18()
    random = rand(Truncated(Normal(.077, .19), -.47, .46), 10000)
    a = reshape(random, length(random),1)
    df = DataFrame(a,["y18return"])

    merged = y17()
    df2 = DataFrame(y18addfunds=repeat(21000:21000,inner=10000))
    merged2 = hcat(merged,df,df2)
    
    merged2[!,:y18total] = merged2[!,:y17return] .* merged2[!,:y17total] + merged2[!,:y17total] + merged2[!, :y18addfunds]
    # merged
    merged2
end

y18()

function y19()
    random = rand(Truncated(Normal(.077, .19), -.47, .46), 10000)
    a = reshape(random, length(random),1)
    df = DataFrame(a,["y19return"])

    merged = y18()
    df2 = DataFrame(y19addfunds=repeat(21000:21000,inner=10000))
    merged2 = hcat(merged,df,df2)
    
    merged2[!,:y19total] = merged2[!,:y18return] .* merged2[!,:y18total] + merged2[!,:y18total] + merged2[!, :y19addfunds]
    # merged
    merged2
end

y19()


function y20()
    random = rand(Truncated(Normal(.077, .19), -.47, .46), 10000)
    a = reshape(random, length(random),1)
    df = DataFrame(a,["y20return"])

    merged = y19()
    df2 = DataFrame(y20addfunds=repeat(21000:21000,inner=10000))
    merged2 = hcat(merged,df,df2)
    
    merged2[!,:y20total] = merged2[!,:y19return] .* merged2[!,:y19total] + merged2[!,:y19total] + merged2[!, :y20addfunds]
    # merged
    merged2
end

y20()

# %%
pd = pyimport("pandas")
# Out:
# PyError (PyImport_ImportModule
#
# The Python package pandas could not be imported by pyimport. Usually this means
# that you did not install pandas in the Python version being used by PyCall.
#
# PyCall is currently configured to use the Julia-specific Python distribution
# installed by the Conda.jl package.  To install the pandas module, you can
# use `pyimport_conda("pandas", PKG)`, where PKG is the Anaconda
# package that contains the module pandas, or alternatively you can use the
# Conda package directly (via `using Conda` followed by `Conda.add` etcetera).
#
# Alternatively, if you want to use a different Python distribution on your
# system, such as a system-wide Python (as opposed to the Julia-specific Python),
# you can re-configure PyCall with that Python.   As explained in the PyCall
# documentation, set ENV["PYTHON"] to the path/name of the python executable
# you want to use, run Pkg.build("PyCall"), and re-launch Julia.
#
# ) <class 'ModuleNotFoundError'>
# ModuleNotFoundError("No module named 'pandas'")
#
#
# Stacktrace:
#  [1] pyimport(name::String)
#    @ PyCall C:\Users\lizba\.julia\packages\PyCall\ygXW2\src\PyCall.jl:558
#  [2] top-level scope
#    @ In[108]:1
#  [3] eval
#    @ .\boot.jl:368 [inlined]
#  [4] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1428

# %%
# combine all functions and subset to the total $ retuirn in year 20
function make_model()
    df = y20()
   select!(df,[:y20total]) 
    
end

make_model()


# turn into a matrix
# sadly can't seem to turn scientific notation off
df = make_model()
M = Matrix(df)
#show(df)
##using PyCall

df
# Import the pandas library
#pandas = pyimport("pandas")

# Create a sample dataframe using pandas
#df = pandas.DataFrame(A = [1, 2, 3, 4, 5])

# Display the dataframe
#display(df)

# Use a pandas function to calculate the mean of the data
#mean = pandas.mean(df["A"])

# Display the mean
#println(mean)

#show(df,allrows=true)
df
typeof(M)
# Out:
# Matrix{Float64} (alias for Array{Float64, 2})

# %%
#output of model, unable to write to file at the time,every row represent a potential outcome
df
# Out:
# 10000×1 DataFrame
#    Row │ y20total
#        │ Float64
# ───────┼────────────────
#      1 │      5.72998e5
#      2 │ 694696.0
#      3 │      1.38206e6
#      4 │      7.71644e5
#      5 │      6.66172e5
#      6 │      1.50294e6
#      7 │      1.47645e6
#      8 │      8.55396e5
#      9 │      1.32744e6
#     10 │      1.68888e6
#     11 │      6.80706e5
#    ⋮   │       ⋮
#   9991 │      3.31048e5
#   9992 │      5.25419e5
#   9993 │      1.6047e6
#   9994 │      1.76672e6
#   9995 │      4.86942e5
#   9996 │      7.80223e5
#   9997 │ 508247.0
#   9998 │      6.72239e5
#   9999 │      9.49283e5
#  10000 │      5.27019e5
#        9979 rows omitted

# %%
using Statistics

vec = reshape(M, :)

# calculate the 90th percentile of the vector
p90 = quantile(vec, 0.9)
p80 = quantile(vec,.8)
p70 = quantile(vec, .7)
#p60 = quantile(vec, .6)
p10 = quantile(vec, .1)

# print the 90th percentile
println(p90)
println(p80)
println(p70)
println(p10)
# Out:
# 1.5411852951793224e6
# 1.203964825063599e6
# 1.021698721013244e6
# 405890.6288150075

# %%
str = "You have a 90 percent chance of having $p90 after 20 years."
# Out:
# "You have a 90 percent chance of having 1.5411852951793224e6 after 20 years."

# %%
str2 = "I don't get this, should the higher of the percentile be a lower number?"
# Out:
# "I don't get this, should the higher of the percentile be a lower number?"

# %%
using Plots
# Create a histogram of the values in the Matrix
histogram(df, bins = 10)
# Out:
# Cannot convert DataFrame to series data for plotting
#
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] _prepare_series_data(x::DataFrame)
#     @ RecipesPipeline C:\Users\lizba\.julia\packages\RecipesPipeline\XxUHt\src\series.jl:8
#   [3] _series_data_vector(x::DataFrame, plotattributes::Dict{Symbol, Any})
#     @ RecipesPipeline C:\Users\lizba\.julia\packages\RecipesPipeline\XxUHt\src\series.jl:36
#   [4] macro expansion
#     @ C:\Users\lizba\.julia\packages\RecipesPipeline\XxUHt\src\series.jl:129 [inlined]
#   [5] apply_recipe(plotattributes::AbstractDict{Symbol, Any}, #unused#::Type{RecipesPipeline.SliceIt}, x::Any, y::Any, z::Any)
#     @ RecipesPipeline C:\Users\lizba\.julia\packages\RecipesBase\6AijY\src\RecipesBase.jl:299
#   [6] _process_userrecipes!(plt::Any, plotattributes::Any, args::Any)
#     @ RecipesPipeline C:\Users\lizba\.julia\packages\RecipesPipeline\XxUHt\src\user_recipe.jl:38
#   [7] recipe_pipeline!(plt::Any, plotattributes::Any, args::Any)
#     @ RecipesPipeline C:\Users\lizba\.julia\packages\RecipesPipeline\XxUHt\src\RecipesPipeline.jl:72
#   [8] _plot!(plt::Plots.Plot, plotattributes::Any, args::Any)
#     @ Plots C:\Users\lizba\.julia\packages\Plots\FCUr0\src\plot.jl:231
#   [9] #plot#149
#     @ C:\Users\lizba\.julia\packages\Plots\FCUr0\src\plot.jl:106 [inlined]
#  [10] histogram(args::Any; kw::Base.Pairs{Symbol, V, Tuple{Vararg{Symbol, N}}, NamedTuple{names, T}} where {V, N, names, T<:Tuple{Vararg{Any, N}}})
#     @ Plots C:\Users\lizba\.julia\packages\RecipesBase\6AijY\src\RecipesBase.jl:428
#  [11] top-level scope
#     @ In[129]:4
#  [12] eval
#     @ .\boot.jl:368 [inlined]
#  [13] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base .\loading.jl:1428

# %% [markdown]
# DISCLAIMER: This is a educational tool and not financial advice. Assume a low degree of confidence at present for the intial model.
